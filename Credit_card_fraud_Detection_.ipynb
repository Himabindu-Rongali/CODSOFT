# %% [markdown]
# <a href="https://colab.research.google.com/github/Himabindu-Rongali/CODSOFT/blob/main/Credit_card_fraud_Detection_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
train_path = "/content/drive/MyDrive/archive (2)/fraudTrain.csv"
train = pd.read_csv(train_path)

# %%
test_path = "/content/drive/MyDrive/archive (2)/fraudTest.csv"
test = pd.read_csv(test_path)

# %%
train.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
test.tail()
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 555714      555714   2020-12-31 23:59:07    30560609640617
# 555715      555715   2020-12-31 23:59:09  3556613125071656
# 555716      555716   2020-12-31 23:59:15  6011724471098086
# 555717      555717   2020-12-31 23:59:24     4079773899158
# 555718      555718   2020-12-31 23:59:34  4170689372027579
#
#                      merchant        category     amt    first     last  \
# 555714  fraud_Reilly and Sons  health_fitness   43.77  Michael    Olson
# 555715   fraud_Hoppe-Parisian       kids_pets  111.84     Jose  Vasquez
# 555716        fraud_Rau-Robel       kids_pets   86.88      Ann   Lawson
# 555717  fraud_Breitenberg LLC          travel    7.99     Eric  Preston
# 555718      fraud_Dare-Marvin   entertainment   38.13   Samuel     Frey
#
#        gender                      street  ...      lat      long  city_pop  \
# 555714      M         558 Michael Estates  ...  40.4931  -91.8912       519
# ...

# %%
train.shape
# Out:
# (1296675, 23)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1296675 non-null  int64
#  1   trans_date_trans_time  1296675 non-null  object
#  2   cc_num                 1296675 non-null  int64
#  3   merchant               1296675 non-null  object
#  4   category               1296675 non-null  object
#  5   amt                    1296675 non-null  float64
#  6   first                  1296675 non-null  object
#  7   last                   1296675 non-null  object
#  8   gender                 1296675 non-null  object
#  9   street                 1296675 non-null  object
#  10  city                   1296675 non-null  object
#  11  state                  1296675 non-null  object
#  12  zip                    1296675 non-null  int64
#  13  lat                    1296675 non-null  float64
# ...

# %%
train.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.experimental import enable_halving_search_cv
from sklearn.metrics import accuracy_score, mean_absolute_error ,mean_squared_error, confusion_matrix, median_absolute_error,classification_report, f1_score,recall_score,precision_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import HalvingRandomSearchCV,RandomizedSearchCV
seed = 39

# %%
train['trans_date_trans_time']=pd.to_datetime(train['trans_date_trans_time'])
train['trans_date']=train['trans_date_trans_time'].dt.strftime('%Y-%m-%d')
train['trans_date']=pd.to_datetime(train['trans_date'])
train['dob']=pd.to_datetime(train['dob'])

test['trans_date_trans_time']=pd.to_datetime(test['trans_date_trans_time'])
test['trans_date']=test['trans_date_trans_time'].dt.strftime('%Y-%m-%d')
test['trans_date']=pd.to_datetime(test['trans_date'])
test['dob']=pd.to_datetime(test['dob'])
test.trans_date.head(),test.dob.head(),train.trans_date.head(),train.dob.head()

train.drop("Unnamed: 0",axis=1,inplace=True)
test.drop("Unnamed: 0",axis=1,inplace=True)
train.head()
# Out:
#   trans_date_trans_time            cc_num                            merchant  \
# 0   2019-01-01 00:00:18  2703186189652095          fraud_Rippin, Kub and Mann
# 1   2019-01-01 00:00:44      630423337322     fraud_Heller, Gutmann and Zieme
# 2   2019-01-01 00:00:51    38859492057661                fraud_Lind-Buckridge
# 3   2019-01-01 00:01:16  3534093764340240  fraud_Kutch, Hermiston and Farrell
# 4   2019-01-01 00:03:06   375534208663984                 fraud_Keeling-Crist
#
#         category     amt      first     last gender  \
# 0       misc_net    4.97   Jennifer    Banks      F
# 1    grocery_pos  107.23  Stephanie     Gill      F
# 2  entertainment  220.11     Edward  Sanchez      M
# 3  gas_transport   45.00     Jeremy    White      M
# 4       misc_pos   41.96      Tyler   Garcia      M
#
#                          street            city  ...      long  city_pop  \
# 0                561 Perry Cove  Moravian Falls  ...  -81.1781      3495
# ...

# %%
total = pd.concat([test,train])
print(total.info())

total["is_fraud_cat"]=total.is_fraud.apply(lambda x: "T" if x==1 else "F")
total["is_fraud_cat"].astype("object")

totalcat=total.select_dtypes(include=['object'])

total[totalcat.columns]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1852394 entries, 0 to 1296674
# Data columns (total 23 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   trans_date_trans_time  datetime64[ns]
#  1   cc_num                 int64
#  2   merchant               object
#  3   category               object
#  4   amt                    float64
#  5   first                  object
#  6   last                   object
#  7   gender                 object
#  8   street                 object
#  9   city                   object
#  10  state                  object
#  11  zip                    int64
#  12  lat                    float64
#  13  long                   float64
#  14  city_pop               int64
#  15  job                    object
#  16  dob                    datetime64[ns]
#  17  trans_num              object
#  18  unix_time              int64
#  19  merch_lat              float64
#  20  merch_long             float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(total[total['is_fraud_cat'] == "T"].category)

plt.xticks(rotation=90)

plt.savefig('fraud_by_category.pdf', bbox_inches='tight', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'total' is your DataFrame and it contains 'is_fraud_cat' and 'state' columns
# Filter the data to include only fraudulent transactions
fraud_data = total[total['is_fraud_cat'] == "T"]

# Calculate the count of frauds by state and get the top 10 states
top_states = fraud_data['state'].value_counts().head(10).index

# Filter the fraud_data to include only the top 10 states
top_fraud_data = fraud_data[fraud_data['state'].isin(top_states)]

# Now create the count plot for only the top 10 states
fig, ax = plt.subplots()
plt.rcParams.update({'font.size': 8})
sns.countplot(x='state', data=top_fraud_data, order=top_states)
plt.xticks(rotation=45)
plt.title("Number of Credit Card Frauds by State")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 8})

# Plot the top 10 cities with the most fraudulent transactions
total[total['is_fraud_cat'] == "T"]["city"].value_counts().head(10).plot(kind="bar")

plt.title("Number of Credit Card Frauds by City")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 8})

# Plot the top 10 cities with the most fraudulent transactions
total[total['is_fraud_cat'] == "T"]["job"].value_counts().head(10).plot(kind="bar")

plt.title("Number of Credit Card Frauds by Job")
plt.show()

# %%
import numpy as np

#finding numerical columns in 'total', not 'test'
totalnum= total.select_dtypes(include=np.number)
total[totalnum.columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1852394 entries, 0 to 1296674
# Data columns (total 7 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   cc_num     int64
#  1   amt        float64
#  2   gender     int64
#  3   zip        int64
#  4   city_pop   int64
#  5   unix_time  int64
#  6   is_fraud   int64
# dtypes: float64(1), int64(6)
# memory usage: 113.1 MB

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1852394 entries, 0 to 1296674
# Data columns (total 25 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   cc_num                   int64
#  1   merchant                 object
#  2   amt                      float64
#  3   first                    object
#  4   last                     object
#  5   gender                   int64
#  6   street                   object
#  7   zip                      int64
#  8   city_pop                 int64
#  9   trans_num                object
#  10  unix_time                int64
#  11  is_fraud                 int64
#  12  category_food_dining     bool
#  13  category_gas_transport   bool
#  14  category_grocery_net     bool
#  15  category_grocery_pos     bool
#  16  category_health_fitness  bool
#  17  category_home            bool
#  18  category_kids_pets       bool
#  19  category_misc_net        bool
#  20  category_misc_pos        bool
# ...

# %%
total.drop(['merchant', 'first', 'last', 'street', 'trans_num'], axis=1, inplace=True)
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1852394 entries, 0 to 1296674
# Data columns (total 20 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   cc_num                   int64
#  1   amt                      float64
#  2   gender                   int64
#  3   zip                      int64
#  4   city_pop                 int64
#  5   unix_time                int64
#  6   is_fraud                 int64
#  7   category_food_dining     bool
#  8   category_gas_transport   bool
#  9   category_grocery_net     bool
#  10  category_grocery_pos     bool
#  11  category_health_fitness  bool
#  12  category_home            bool
#  13  category_kids_pets       bool
#  14  category_misc_net        bool
#  15  category_misc_pos        bool
#  16  category_personal_care   bool
#  17  category_shopping_net    bool
#  18  category_shopping_pos    bool
#  19  category_travel          bool
# dtypes: bool(13), float64(1), int64(6)
# ...

# %%
from sklearn.model_selection import train_test_split

X = total.drop('is_fraud', axis=1)
Y = total['is_fraud']

# Split into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=39)

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize and train Logistic Regression model
model = LogisticRegression(max_iter=1000, random_state=39)
model.fit(X_train_scaled, Y_train)

# Make predictions
Y_pred = model.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(Y_test, Y_pred)
conf_matrix = confusion_matrix(Y_test, Y_pred)
class_report = classification_report(Y_test, Y_pred)

print(f"Accuracy: {accuracy:.4f}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 0.9944
# Confusion Matrix:
# [[552586    263]
#  [  2870      0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00    552849
#            1       0.00      0.00      0.00      2870
#
#     accuracy                           0.99    555719
#    macro avg       0.50      0.50      0.50    555719
# weighted avg       0.99      0.99      0.99    555719
